# %%
using LinearAlgebra
using DSP
using Statistics
using PyPlot

# %%
#7.15 (B)

u = rand([-1,1],50)
c = [1, 0.7, -0.3]
h = [0.9, -0.5, 0.5, -0.4, 0.3, -0.3, 0.2, -0.1]

y = conv(c,u)
z = conv(h, y)

a = 1:50

stem(a,u)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000006E879C70>, PyObject <matplotlib.collections.LineCollection object at 0x000000006E868E20>, PyObject <matplotlib.lines.Line2D object at 0x000000006E892040>)

# %%
stem(y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000006FAC2DC0>, PyObject <matplotlib.collections.LineCollection object at 0x000000006FAB4F10>, PyObject <matplotlib.lines.Line2D object at 0x000000006FADB190>)

# %%
stem(z)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000006FB28040>, PyObject <matplotlib.collections.LineCollection object at 0x000000006FB0C040>, PyObject <matplotlib.lines.Line2D object at 0x000000006FB283D0>)

# %%
#A7.1
# (A)

include("channel_equalization_data.jl")
stem(c)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000006FB9B220>, PyObject <matplotlib.collections.LineCollection object at 0x000000006FB8BC40>, PyObject <matplotlib.lines.Line2D object at 0x000000006FB9B5B0>)

# %%
stem(h)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000006FC05FA0>, PyObject <matplotlib.collections.LineCollection object at 0x000000006FC05A00>, PyObject <matplotlib.lines.Line2D object at 0x000000006FC16370>)

# %%
stem(conv(c,h))

#Observation
# Here we can
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000007FD12430>, PyObject <matplotlib.collections.LineCollection object at 0x000000007FCFED90>, PyObject <matplotlib.lines.Line2D object at 0x000000007FD127C0>)

# %%
# (B)
stem(s[1:100])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000007FDA4850>, PyObject <matplotlib.collections.LineCollection object at 0x000000007FD7F0A0>, PyObject <matplotlib.lines.Line2D object at 0x000000007FDA4BE0>)

# %%
y = conv(c, s)
scap = y .> 0.5 
stem(y[1:100])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000007FE7D0D0>, PyObject <matplotlib.collections.LineCollection object at 0x000000007FE088E0>, PyObject <matplotlib.lines.Line2D object at 0x000000007FE7D460>)

# %%
ycap = conv(h, y)
scapeq = ycap .> 0.5
stem(ycap[1:100])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (PyObject <matplotlib.lines.Line2D object at 0x000000007FF062B0>, PyObject <matplotlib.collections.LineCollection object at 0x000000007FECEAC0>, PyObject <matplotlib.lines.Line2D object at 0x000000007FF06640>)
